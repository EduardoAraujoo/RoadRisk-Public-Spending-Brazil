# %%
import pandas as pd
import os

file_path = "../data/processed/occ_mg_master.parquet"

if os.path.exists(file_path):
    print("✅ File found! Loading...")
    df = pd.read_parquet(file_path)
    print("✅ Load complete!")
else:
    print("❌ File NOT found. Check your path.")
# Out:
# ✅ File found! Loading...
# ✅ Load complete!

# %%
df.head()
# Out:
#       id data_inversa     dia_semana   horario  uf   br     km     municipio  \
# 0  123.0   2017-01-01        domingo  11:50:00  MG  262  483.1  BOM DESPACHO
# 1  185.0   2017-01-01        domingo  16:30:00  MG  381  672.8       PERDOES
# 2  228.0   2017-01-01        domingo  18:20:00  MG  116  702.8        MURIAE
# 3  351.0   2017-01-02  segunda-feira  04:57:00  MG  381  567.1      ITAGUARA
# 4  356.0   2017-01-02  segunda-feira  06:20:00  MG   40  520.5      CONTAGEM
#
#                                       causa_acidente          tipo_acidente  \
# 0                                  Condutor Dormindo        Colisão lateral
# 1                 Não guardar distância de segurança  Derramamento de carga
# 2  Desobediência às normas de trânsito pelo condutor    Colisão transversal
# 3                                  Condutor Dormindo       Colisão traseira
# 4                        Falta de Atenção à Condução       Colisão traseira
#
#    ... ilesos ignorados feridos veiculos   latitude  longitude regional  \
# 0  ...      2         1       0        3 -19.785618 -45.309561  SPRF-MG
# 1  ...      0         0       1        1 -21.094537 -45.075492  SPRF-MG
# 2  ...      2         1       0        3 -21.124707 -42.381322  SPRF-MG
# 3  ...     47         0       0        2 -20.404118 -44.516957  SPRF-MG
# 4  ...      1         0       3        2 -19.852095 -44.072701  SPRF-MG
#
#    delegacia             uop  year_reference
# 0   DEL08-MG  UOP03-DEL08-MG            2017
# 1   DEL04-MG  UOP02-DEL04-MG            2017
# 2   DEL07-MG  UOP02-DEL07-MG            2017
# 3   DEL04-MG  UOP03-DEL04-MG            2017
# 4   DEL01-MG  UOP03-DEL01-MG            2017
#
# [5 rows x 31 columns]

# %%
import pandas as pd

# Carregando Ocorrências (Geral)
df_occ = pd.read_parquet("../data/processed/occ_mg_master.parquet")

# Carregando Pessoas (Detalhado)
df_pers = pd.read_parquet("../data/processed/pers_mg_master.parquet")

print(f"Total de Ocorrências em MG: {len(df_occ)}")
print(f"Total de Pessoas envolvidas em MG: {len(df_pers)}")
# Out:
# Total de Ocorrências em MG: 83409
# Total de Pessoas envolvidas em MG: 561796
